# %%
# Implementasi Fungsi f(x) = 3x - 7 untuk -5 < x < 5, x ∈ Z
# a) Metode Konvensional
print("Metode Konvensional:")
for x in range(-4, 5):
    print(f"f({x}) = {3*x - 7}")
# Out:
# Metode Konvensional:
# f(-4) = -19
# f(-3) = -16
# f(-2) = -13
# f(-1) = -10
# f(0) = -7
# f(1) = -4
# f(2) = -1
# f(3) = 2
# f(4) = 5

# %%
# b) Menggunakan def
def f(x):
    return 3*x - 7

print("Menggunakan def:")
for x in range(-4, 5):
    print(f"f({x}) = {f(x)}")
# Out:
# Menggunakan def:
# f(-4) = -19
# f(-3) = -16
# f(-2) = -13
# f(-1) = -10
# f(0) = -7
# f(1) = -4
# f(2) = -1
# f(3) = 2
# f(4) = 5

# %%
# c) Dengan List (anggota domain)
domain = list(range(-4, 5))
hasil = [3*x - 7 for x in domain]

print("Domain:", domain)
print("Hasil fungsi:", hasil)
# Out:
# Domain: [-4, -3, -2, -1, 0, 1, 2, 3, 4]
# Hasil fungsi: [-19, -16, -13, -10, -7, -4, -1, 2, 5]

# %%
import numpy as np
import matplotlib.pyplot as plt

# a) f(x) = 2x | -100 < x < 100
x = np.arange(-99, 100)
y = 2 * x

plt.figure()
plt.plot(x, y, label="f(x) = 2x", color='blue')
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.title("Grafik f(x) = 2x")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# b) f(x) = x² + 3x - 10 | -20 < x < 20
x = np.arange(-19, 20)
y = x**2 + 3*x - 10

plt.figure()
plt.plot(x, y, label="f(x) = x² + 3x - 10", color='green')
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.title("Grafik f(x) = x² + 3x - 10")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# c) f(x) = x³ - 10 | -10 < x < 10
x = np.arange(-9, 10)
y = x**3 - 10

plt.figure()
plt.plot(x, y, label="f(x) = x³ - 10", color='purple')
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.title("Grafik f(x) = x³ - 10")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# d) f(x) = sin(x) | -2π < x < 2π
x = np.linspace(-2*np.pi, 2*np.pi, 200)
y = np.sin(x)

plt.figure()
plt.plot(x, y, label="f(x) = sin(x)", color='red')
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.title("Grafik f(x) = sin(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# e) f(x) = cos(x) | -2π < x < 2π
x = np.linspace(-2*np.pi, 2*np.pi, 200)
y = np.cos(x)

plt.figure()
plt.plot(x, y, label="f(x) = cos(x)", color='orange')
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.title("Grafik f(x) = cos(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()
